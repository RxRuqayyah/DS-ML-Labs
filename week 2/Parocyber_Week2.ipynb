# %%
letters= ['a','b','c','d','e']
letters
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
#append
letters.append('f')
print(letters)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %%
#extend
letters.extend(['g','h'])
print(letters)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']

# %%
#insert
letters.insert(0,1)
print(letters)
# Out:
# [1, 'a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']

# %%
#remove
letters.remove('a')
print(letters)
# Out:
# [1, 'b', 'c', 'd', 'e', 'f', 'g', 'h']

# %%
letters.append('a')
letters
# Out:
# [1, 'b', 'c', 'd', 'e', 'f', 'g', 'h', ['a', 'a'], 'a']

# %%
letters.remove(['a','a'])
letters
# Out:
# [1, 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'a']

# %%
 #pop
 pop_element = letters.pop(5)
 print(pop_element)
 print(letters)
# Out:
# f
# [1, 'b', 'c', 'd', 'e', 'g', 'h', 'a']

# %%
#index
index= letters.index('e')
print(index)
# Out:
# 4

# %%
#count
count=letters.count('h')
print(count)
# Out:
# 1

# %%
#sort
letters.remove(1) # Remove the integer to make the list sortable
letters.sort()
print(letters)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'g', 'h']

# %%
#reverse
letters.reverse()
print(letters)
# Out:
# ['h', 'g', 'e', 'd', 'c', 'b', 'a']

# %%
#Tuple
Ruqayyah=('a','b','c','d','e')
Ruqayyah
# Out:
# ('a', 'b', 'c', 'd', 'e')

# %%
#count
count=Ruqayyah.count('a')
print(count)
# Out:
# 1

# %%
#index
index=Ruqayyah.index('e')
print(index)
# Out:
# 4

# %%
print(Ruqayyah[3])
# Out:
# d

# %%
#dictionary: unordered collection, key-values pairs
myDict=dict(name='Ruqayyah',age=22, city= 'lagos')
myDict
# Out:
# {'name': 'Ruqayyah', 'age': 22, 'city': 'lagos'}

# %%
myDict=dict([('name','Ruqayyah'),('age',22),('city','lagos')])
myDict
# Out:
# {'name': 'Ruqayyah', 'age': 22, 'city': 'lagos'}

# %%
myDict={'name':'Ruqayyah','age':22,'city':'lagos'}
myDict
# Out:
# {'name': 'Ruqayyah', 'age': 22, 'city': 'lagos'}

# %%
age=myDict.get('age')
print(age)
# Out:
# 22

# %%
myDictionary=dict([('name',['mary','tope','aminah']),('age', [23,22,25]), ('city', ['lagos','abuja','ibadan'])])
myDictionary
# Out:
# {'name': ['mary', 'tope', 'aminah'],
#  'age': [23, 22, 25],
#  'city': ['lagos', 'abuja', 'ibadan']}

# %%
items=myDictionary.items()
print(items)
# Out:
# dict_items([('name', ['mary', 'tope', 'aminah']), ('age', [23, 22, 25]), ('city', ['lagos', 'abuja', 'ibadan'])])

# %%
keys=myDictionary.keys()
keys
# Out:
# dict_keys(['name', 'age', 'city'])

# %%
values=myDictionary.values()
values
# Out:
# dict_values([['mary', 'tope', 'aminah'], [23, 22, 25], ['lagos', 'abuja', 'ibadan']])

# %%
myDictionary.update({'gender':['Female','Female','Female']})
myDictionary
# Out:
# {'name': ['mary', 'tope', 'aminah'],
#  'age': [23, 22, 25],
#  'city': ['lagos', 'abuja', 'ibadan'],
#  'gender': ['Female', 'Female', 'Female']}
